# %%
import nltk # need to insatll verison 3.8.1 for this code to work 
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict, Counter
import spacy

#from nrclex import NRCLex
# requiremnet to download necessary data for NRCLex run simply run python -m textblob.download_corpora
# or use the NLTK downloader to download the missing data: http://nltk.org/data.html


# Download required NLTK resources
try:
    nltk.download('punkt')
    nltk.download('punkt_tab')  # This is the specific missing resource
    nltk.download('averaged_perceptron_tagger')
    nltk.download('wordnet')
    nltk.download('omw-1.4')
except:
    pass

# necessary steps for NRCLex to run
import subprocess
try:
    subprocess.run(['python', '-m', 'textblob.download_corpora'])
except:
    pass

# finally importing it
from nrclex import NRCLex
# make sure to do !pip install openpyxl beforehand
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\daran\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\daran\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\daran\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\daran\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\daran\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\daran\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
# opening dataset
van_gogh_data = pd.read_excel('cleaned_van_gogh_letters.xlsx')

van_gogh_data.head()
# Out:
#   Letter              From             To   Location  \
# 0    191  Vincent van Gogh  Theo van Gogh  The Hague
# 1    554  Vincent van Gogh  Theo van Gogh    Antwerp
# 2    238  Vincent van Gogh  Theo van Gogh  The Hague
# 3    361  Vincent van Gogh  Theo van Gogh  The Hague
# 4    445  Vincent van Gogh  Theo van Gogh     Nuenen
#
#                                                 Date  \
# 0  between Thursday, 1 and Saturday, 3 December 1881
# 1                on or about Friday, 22 January 1886
# 2                                Friday, 9 June 1882
# 3                on or about Wednesday, 11 July 1883
# 4                           Wednesday, 30 April 1884
#
#                                        Original Text  \
# 0  den Haag Dec 1881. Waarde Theo, Zoo als ge zie...
# 1  Waarde Theo, Een paar dagen heb ik nu ginder g...
# 2  Waarde Theo, Weinig dingen hebben in den laats...
# 3  Waarde Theo, Naar Uw brief had ik reeds min of...
# 4  Waarde Theo, Hartelijk gefeliciteerd met Uw ve...
#
#                                          Translation  \
# 0  The Hague, Dec. 1881. My dear Theo, As you see...
# 1  My dear Theo, I’ve been painting there for a f...
# 2  My dear Theo, Few things have given me so much...
# 3  My dear Theo, I had already been looking out f...
# 4  My dear Theo, Many happy returns of the day. I...
#
#                                               Note 1  \
# 0  Mauve the Strickers Regarding ’s plan to visit...
# 1  It emerges from that Van Gogh painted a large ...
# 2  Sien father When exactly left is not known. On...
# 3  The exhibition at Galerie Georges Petit. At th...
# 4                         Theo was 27 on 1 May 1884.
#
#                                               Note 2  \
# 0  F 63 / JH 920 (). See cat. Amsterdam 1999, p. ...
# 1      Vinck In the ‘Classical Statues’ class with :
# 2            Means: ‘het ziekenhuis’ (the hospital).
# 3  Jules Dupré Rousseau Troyon There were four wo...
# 4  Boussod, Valadon & Cie Mr van Gogh This remark...
#
#                                               Note 3  ... Note 119 Note 120  \
# 0  Mauve The boarding-house must therefore have b...  ...      NaN      NaN
# 1  See for this painting class: cat. Amsterdam 20...  ...      NaN      NaN
# 2  Armand Cassagne Van Gogh might be referring he...  ...      NaN      NaN
# 3  Constant Troyon Which particular painting of a...  ...      NaN      NaN
# 4  F 30 / JH 479 Most probably (), which is indee...  ...      NaN      NaN
#
#   Note 121 Note 122 Note 123 Note 124 Note 125 Note 126 Note 127 Note 128
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
# [5 rows x 135 columns]

# %% [markdown]
# # Cleaning the data

# %%
# only selecting letters sent by Van Gogh
letters = van_gogh_data[van_gogh_data['From'] == 'Vincent van Gogh']

# %%
letters["Translation"].isna().sum() # it appears that two letters have not been translated to English
# we will drop this before continuing our analysis
# Out:
# 2

# %%
letters = letters.dropna(subset=["Translation"])

# %%
# creating a copy of df to avoid modifying original 
sentiment_letters = letters.copy()

# %% [markdown]
# # Sentiment Analysis of All Letters
# ## VADER

# %%
# initializing analyzer
sentiment_analyzer = SentimentIntensityAnalyzer()

# applying sentiment analysis to all letters in English
sentiment_scores = sentiment_letters["Translation"].apply(sentiment_analyzer.polarity_scores)

# adding sentiment scores as new columns to our dataset
sentiment_letters['negative'] = [score["neg"] for score in sentiment_scores]
sentiment_letters['neutral'] = [score["neu"] for score in sentiment_scores]
sentiment_letters['positive'] = [score["pos"] for score in sentiment_scores]
sentiment_letters['compound'] = [score["compound"] for score in sentiment_scores] # combination of previously mentioned sentiment scores

# adding overall sentiment category: positive, neutral, negative
# if compound score >= 0.05 classified as positive, compound score <= -0.05, else neutral
sentiment_letters['sentiment'] = sentiment_letters['compound'].apply(
    lambda x: 'Positive' if x >= 0.05 else ('Negative' if x <= -0.05 else 'Neutral'))

# printing sentiment distribution
print("\nSentiment Distribution:")
print(sentiment_letters['sentiment'].value_counts())
# Out:
# Sentiment Distribution:
# sentiment
# Positive    789
# Negative     27
# Neutral       2
# Name: count, dtype: int64

# %%
# distribution of compound sentiment scores
ax = sns.histplot(data= sentiment_letters, x='compound', bins=10)
ax.set_title('Distribution of Sentiment Scores in Van Gogh\'s Letters')
ax.set_xlabel('Compound Sentiment Score')
plt.show()

# %%
# Plot 2: Overall sentiment categories
sentiment_counts = sentiment_letters['sentiment'].value_counts()
# setting the dimensions of the plot
fig, ax = plt.subplots(figsize=(10, 6))
sns.barplot(sentiment_counts, ax=ax, orient = 'h', color = 'red')

#ax2 = sns.barplot(sentiment_counts, orient = "h", color='steelblue')
ax.set_title('Distribution of Sentiment Categories')
ax.set_ylabel('Sentiment Category')
plt.show()

# %%
# gathering letter with most negative score to test reliability of algorithm
most_negative_letter = sentiment_letters[sentiment_letters["compound"] == sentiment_letters["compound"].min()]

# displaying results
#print(f"Minimum compound score: {sentiment_letters["compound"].min()}")
print("\nMost negative letter(s):")
most_negative_letter["Translation"].values
# Out:
# Most negative letter(s):
# array(['My dear Theo, You’re quite right to ask why I haven’t replied to you yet. I did indeed receive your letter with 150 francs enclosed. I began a letter to you, chiefly to thank you because you seemed to have understood my letter, and also to tell you that I only on 100 francs, but actually find it hard to manage on it as long as things don’t progress. But nevertheless, if it’s 150 francs, there’s a 50 francs windfall extra in so far as our agreement was only 100 francs, and if we’re only half good friends I wouldn’t want to accept more. However, I couldn’t finish that letter, and since then I’ve wanted to write to you but I haven’t been able to find the right words. Something has happened, Theo, which most of the people here know or suspect about — nor may ever know, so keep as silent as the grave about it — but which is terrible. To tell you everything I’d have to write a book — I can’t do that. has taken poison — in a moment of despair, when she’d spoken to her family and people spoke ill of her and me, and she became upset
every day Thou hast allowed me, I’ll bring Thee higher, purer praise. Praise, Christian, there on your left hand, And on your right, is God – When I have no more strength to stand, When anguished, there is God – When loving hand of faithful friend Helps not, there is God – In death and agony at life’s end, Yes, everywhere is God. How I long for Christmas and to see all of you, old boy, it seems to me that I’ve grown years older in these few months. The panting hart, the hunt escapèd, Cries no harder for the pleasure Of fresh flowing streams of water Than my soul doth long for God. Yea, my soul thirsts for the Lord, God of life, oh when shall I Approach Thy sight, and drawing nigh, Give Thee praise in Thine own house. Why art thou cast down, my soul, Disquieted in me, oh why? Foster again the faith of old, Rejoice in praising Him most high. Oft hath he taken your distress And turned it into happiness. Hope in Him, eyes heavenward raised, For to my God I still give praise. My boy, if illness and difficulties come to meet us, let us thank Him for bringing us into these hours – and let us not forget meekness, for it is written: On this man will I look, even on him who is poor and sorrowful and who trembleth at My word. Yesterday evening I went to Richmond again, and took a walk there on a large common surrounded by trees, and houses around it, above which the tower rose. Dew lay on the grass and it was growing dark; on one side the sky was still full of the glow of the sun that had just set there, on the other side the moon was rising. An old lady (dressed in black) with lovely grey hair was walking beneath the trees. In the middle of the common, some boys had lit a big fire, which one saw flickering in the distance; I thought of this: when once life’s evening overcomes me, worn down by ills and strife always, for every day Thou hast allowed me, I’ll bring Thee higher, purer praise. Adieu, a handshake in thought from Your most loving brother, Vincent Regards to , , and everyone at ’ and and if you should see someone or other whom I know. Your brother was indeed moved when he stood at the foot of the pulpit and  ...
#       dtype=object)

# %% [markdown]
# ## NRCLex
# Going beyond the extent of the emotion (whether positive/negative) by detecting actual emotions Van Gogh expresses. While VADER looks at the intensity of emotion of each letter, NRCLex classifies text into specific emotion categories (joy, fear, anger, sadness, etc.)

# %%
# making lists to store emotion data
all_emotions = [] # storing all emotions detected
emotion_scores = [] # storing scores of all emotions
primary_emotions = [] # storing the primary emotion
secondary_emotions = [] # storing secondary emotion

# iterating over all letters
for text in sentiment_letters["Translation"]:
    emotion = NRCLex(text)
    emotions_dict = emotion.raw_emotion_scores    
    all_emotions.append(emotions_dict) # storing all emotions present
    total_emotional_words = sum(emotions_dict.values()) # calculating emotion scores (normalized)
    if total_emotional_words > 0: 
        scores = {emotion: count/total_emotional_words for emotion, count in emotions_dict.items()}
    else:
        scores = emotions_dict
    emotion_scores.append(scores)
        
# determining primary and secondary emotions
    if emotion_scores:
        sorted_emotions = sorted(scores.items(), key=lambda x: x[1], reverse=True) # sorting emotion scores by ascending order
        primary_emotions.append(sorted_emotions[0][0] if sorted_emotions else 'neutral') # adding primary emotions to list
        secondary_emotions.append(sorted_emotions[1][0] if len(sorted_emotions) > 1 else 'none') # adding secondary emotions to list
    else:
        primary_emotions.append('neutral') # if no primary emotion deteted setting it as neutral 
        secondary_emotions.append('none') # or none for secondary emotions (as no other main emotion was detected)

# adding emotion columns to dataset so we can make visualizations
sentiment_letters['emotion_scores_NRCLex'] = emotion_scores # emotion scores
sentiment_letters['primary_emotion'] = primary_emotions # primary emotion of each letter
sentiment_letters['secondary_emotion'] = secondary_emotions # secondary emotion of each letter

# %%
sentiment_letters.head(2) # looking at dataset now
# Out:
#   Letter              From             To   Location  \
# 0    191  Vincent van Gogh  Theo van Gogh  The Hague
# 1    554  Vincent van Gogh  Theo van Gogh    Antwerp
#
#                                                 Date  \
# 0  between Thursday, 1 and Saturday, 3 December 1881
# 1                on or about Friday, 22 January 1886
#
#                                        Original Text  \
# 0  den Haag Dec 1881. Waarde Theo, Zoo als ge zie...
# 1  Waarde Theo, Een paar dagen heb ik nu ginder g...
#
#                                          Translation  \
# 0  The Hague, Dec. 1881. My dear Theo, As you see...
# 1  My dear Theo, I’ve been painting there for a f...
#
#                                               Note 1  \
# 0  Mauve the Strickers Regarding ’s plan to visit...
# 1  It emerges from that Van Gogh painted a large ...
#
#                                               Note 2  \
# 0  F 63 / JH 920 (). See cat. Amsterdam 1999, p. ...
# 1      Vinck In the ‘Classical Statues’ class with :
#
#                                               Note 3  ... Note 127 Note 128  \
# 0  Mauve The boarding-house must therefore have b...  ...      NaN      NaN
# 1  See for this painting class: cat. Amsterdam 20...  ...      NaN      NaN
#
#   negative neutral positive compound sentiment  \
# 0    0.052   0.805    0.143   0.9937  Positive
# 1    0.037   0.818    0.145   0.9950  Positive
#
#                                emotion_scores_NRCLex primary_emotion  \
# 0  {'positive': 0.24242424242424243, 'fear': 0.02...        positive
# 1  {'positive': 0.24358974358974358, 'negative': ...        positive
#
#   secondary_emotion
# 0          negative
# 1      anticipation
#
# [2 rows x 143 columns]

# %%
sentiment_letters["primary_emotion"].value_counts()
# Out:
# primary_emotion
# positive        781
# anticipation     19
# negative         11
# trust             5
# neutral           1
# fear              1
# Name: count, dtype: int64

# %%
sentiment_letters["secondary_emotion"].value_counts()
# Out:
# secondary_emotion
# trust           352
# anticipation    247
# negative        129
# joy              57
# positive         30
# none              2
# sadness           1
# Name: count, dtype: int64

# %%
# plotting primary emotions of letters 
ax3 = sns.barplot(sentiment_letters['primary_emotion'].value_counts(), orient = "h", color = "lightgreen")
ax3.set_title('Distribution of Primary Emotions of Letters')
plt.show()

# %%
# plotting primary emotions of letters 
ax3 = sns.barplot(sentiment_letters['secondary_emotion'].value_counts(), orient = "h", color = "lightblue")#sentiment_counts.plot(kind='bar')
ax3.set_title('Distribution of Secondary Emotions of Letters')
plt.show()

# %% [markdown]
# # Validation
# Checking whether the results of both algorithms are in accordance

# %%
# grouping NRCLex emotions into positive and negative
positive_emotions = ['positive','trust', 'anticipation']
negative_emotions = ['negative','fear']
neutral_emotions = ['neutral']

# calculating the extent both algorithms agree

total_letters = len(sentiment_letters) # total number of letters

# number of letters both algorithms labeled with positive emotions
positive_agreement = len(sentiment_letters[
    (sentiment_letters['sentiment'] == 'Positive') & 
    (sentiment_letters['primary_emotion'].isin(positive_emotions))
])

# number of letters both algorithms labeled with negative emotions
negative_agreement = len(sentiment_letters[
    (sentiment_letters['sentiment'] == 'Negative') & 
    (sentiment_letters['primary_emotion'].isin(negative_emotions))
])

# number of letters both algorithms labeled with neutral emotions
neutral_agreement = len(sentiment_letters[
    (sentiment_letters['sentiment'] == 'Neutral') & 
    (sentiment_letters['primary_emotion'].isin(neutral_emotions))
])

# putting it all together in a dictionary 
agreement_stats = {
        'positive_sentiment_positive_emotion': positive_agreement,
        'negative_sentiment_negative_emotion': negative_agreement,
        'neutral_agreement': neutral_agreement,
        'total_agreement': positive_agreement + negative_agreement + neutral_agreement,
        'total_agreement_pct': ((positive_agreement + negative_agreement + neutral_agreement)/total_letters) * 100,
        'total_disagreement': total_letters - (positive_agreement + negative_agreement + neutral_agreement),
        'total_disagreement_pct': 100 - ((positive_agreement + negative_agreement + neutral_agreement)/total_letters) * 100
    }
agreement_stats
# Out:
# {'positive_sentiment_positive_emotion': 784,
#  'negative_sentiment_negative_emotion': 6,
#  'neutral_agreement': 1,
#  'total_agreement': 791,
#  'total_agreement_pct': 96.69926650366747,
#  'total_disagreement': 27,
#  'total_disagreement_pct': 3.3007334963325263}

# %% [markdown]
# # Performing Entity Recognition
# Now that we have explored Van Gogh's overall sentiments and emotions in general, we will explore how he felt towards particular entities. For this we will use the spacy package that is able to extract entities mentioned in text data. The algorithm detects and classifies entitites that are people, organizations, geographical places, etc. For a clearer description check [this](https://towardsdatascience.com/named-entity-recognition-ner-using-spacy-nlp-part-4-28da2ece57c6#:~:text=Text%20Processing%20using%20spaCy%20%7C%20NLP%20Library&text=Named%20Entity%20Recognition%20NER%20works,values%2C%20percentage%2C%20codes%20etc.). We will first define the most commonly mentioned entities.

# %%
# necessary to do to be able to run algorithm
try:
    nlp = spacy.load('en_core_web_sm')
except OSError:
    import subprocess
    subprocess.run(['python', '-m', 'spacy', 'download', 'en_core_web_sm'])
    nlp = spacy.load('en_core_web_sm')

# initializes counters for entity discovery
entity_counter = Counter()
entity_types = defaultdict(set)

# iterating over all letters 
for text in sentiment_letters['Translation']:
    doc = nlp(text)
    for ent in doc.ents: # counting how many times each entity appears 
        entity_counter[ent.text] += 1
        entity_types[ent.text].add(ent.label_)

# filtering frequent entities that appear at least 5 times in the letters 
min_frequency = 5
frequent_entities = { # creating dictionaries for each entity
    entity: {
        'count': count, # how many times it appears in the letters
        'types': list(entity_types[entity]) # what type of entity it is 
    }
    for entity, count in entity_counter.items()
    if count >= min_frequency
}

# %%
frequent_entities # output
# Out:
# {'The Hague': {'count': 174, 'types': ['GPE']},
#  'Theo': {'count': 951, 'types': ['PERSON', 'ORG']},
#  'last Sunday': {'count': 22, 'types': ['DATE']},
#  'Etten': {'count': 37, 'types': ['GPE', 'PRODUCT', 'ORG']},
#  'a few days': {'count': 64, 'types': ['DATE']},
#  'Mauve': {'count': 64, 'types': ['PRODUCT', 'PERSON', 'LOC', 'ORG']},
#  'first': {'count': 726, 'types': ['ORDINAL']},
#  'Het Heike': {'count': 15, 'types': ['PERSON', 'FAC']},
#  '30 guilders': {'count': 6, 'types': ['MONEY']},
#  '100 francs': {'count': 42, 'types': ['MONEY']},
#  'M.': {'count': 6, 'types': ['PERSON', 'NORP']},
#  'Amsterdam': {'count': 131, 'types': ['GPE']},
#  'the spring': {'count': 33, 'types': ['DATE']},
#  'Vincent': {'count': 604, 'types': ['GPE', 'PERSON']},
#  'one': {'count': 1144, 'types': ['CARDINAL']},
#  'Monday': {'count': 29, 'types': ['DATE']},
#  'American': {'count': 11, 'types': ['NORP']},
#  'Paris': {'count': 555, 'types': ['GPE']},
#  '10 guilders': {'count': 23, 'types': ['MONEY']},
#  'about one': {'count': 22, 'types': ['CARDINAL']},
#  'Dickens': {'count': 16, 'types': ['PERSON']},
#  'Jove': {'count': 9, 'types': ['PERSON']},
#  'morning': {'count': 64, 'types': ['TIME']},
#  'calmer': {'count': 8, 'types': ['PERSON']},
#  '3rd': {'count': 16, 'types': ['ORDINAL']},
#  '4th': {'count': 6, 'types': ['ORDINAL']},
#  '6': {'count': 108, 'types': ['CARDINAL', 'DATE']},
#  '9': {'count': 9, 'types': ['CARDINAL']},
#  'Luxembourg': {'count': 27, 'types': ['GPE']},
#  'yesterday': {'count': 154, 'types': ['DATE']},
#  'Yesterday': {'count': 103, 'types': ['DATE']},
#  'last year': {'count': 88, 'types': ['DATE']},
#  'evening': {'count': 176, 'types': ['TIME']},
#  'Gothic': {'count': 12, 'types': ['PERSON', 'NORP', 'ORG']},
#  'Holland': {'count': 179, 'types': ['GPE']},
#  'two': {'count': 830, 'types': ['CARDINAL']},
#  'Scheveningen': {'count': 75, 'types': ['ORG']},
#  'Salon': {'count': 51, 'types': ['EVENT', 'PERSON', 'LOC', 'ORG', 'GPE']},
#  'London': {'count': 187, 'types': ['GPE']},
#  'Brabant': {'count': 68, 'types': ['GPE', 'PERSON', 'ORG']},
#  'Nuenen': {'count': 44, 'types': ['GPE']},
#  'Vincent I’m': {'count': 20, 'types': ['PERSON']},
#  'Rotterdam': {'count': 10, 'types': ['GPE']},
#  'these days': {'count': 141, 'types': ['DATE']},
#  'B.': {'count': 11, 'types': ['ORG', 'PERSON', 'NORP']},
#  'n’t': {'count': 118, 'types': ['GPE']},
#  '3': {'count': 146, 'types': ['CARDINAL']},
#  '3/4': {'count': 6, 'types': ['CARDINAL']},
#  'second': {'count': 130, 'types': ['ORDINAL']},
#  'third': {'count': 29, 'types': ['ORDINAL']},
#  'Spanish': {'count': 10, 'types': ['NORP']},
#  'Dutch': {'count': 132, 'types': ['NORP']},
#  'Friend': {'count': 5, 'types': ['ORG']},
#  'Last year': {'count': 16, 'types': ['DATE']},
#  'English': {'count': 120, 'types': ['LANGUAGE', 'NORP']},
#  'today': {'count': 337, 'types': ['DATE']},
#  'This week': {'count': 37, 'types': ['DATE']},
#  '1': {'count': 100, 'types': ['CARDINAL']},
#  'half': {'count': 106, 'types': ['CARDINAL']},
#  '&c.': {'count': 80, 'types': ['PERSON']},
#  'the day': {'count': 114, 'types': ['DATE']},
#  'the winter': {'count': 40, 'types': ['DATE']},
#  'this morning': {'count': 89, 'types': ['TIME']},
#  'tomorrow': {'count': 80, 'types': ['DATE']},
#  'afternoon': {'count': 18, 'types': ['TIME']},
#  'fig': {'count': 9, 'types': ['ORG']},
#  'republican': {'count': 6, 'types': ['NORP']},
#  '12': {'count': 57, 'types': ['CARDINAL', 'DATE']},
#  'the day before yesterday': {'count': 8, 'types': ['DATE']},
#  'the past few days': {'count': 9, 'types': ['DATE']},
#  'Jo': {'count': 14, 'types': ['PERSON']},
#  'last few days': {'count': 9, 'types': ['DATE']},
#  'the other year': {'count': 5, 'types': ['DATE']},
#  'Gauguin': {'count': 81, 'types': ['PERSON']},
#  'Russell': {'count': 18, 'types': ['PERSON']},
#  'G.': {'count': 12, 'types': ['PERSON']},
#  'Millet': {'count': 66, 'types': ['GPE', 'PERSON']},
#  'a few months': {'count': 7, 'types': ['DATE']},
#  'Les': {'count': 13, 'types': ['GPE', 'ORG']},
#  'I.': {'count': 8, 'types': ['PERSON', 'ORG']},
#  'firstly': {'count': 6, 'types': ['ORDINAL']},
#  'Sorrow': {'count': 17, 'types': ['PRODUCT']},
#  '3 weeks': {'count': 5, 'types': ['DATE']},
#  'Leiden': {'count': 54, 'types': ['GPE', 'PERSON']},
#  'His Hon': {'count': 18, 'types': ['PERSON']},
#  'Christien': {'count': 6, 'types': ['PERSON']},
#  'this week': {'count': 71, 'types': ['DATE']},
#  'every day': {'count': 30, 'types': ['DATE']},
#  'First': {'count': 55, 'types': ['ORDINAL', 'ORG']},
#  'night': {'count': 55, 'types': ['TIME']},
#  'bush': {'count': 25, 'types': ['PERSON']},
#  '2': {'count': 114, 'types': ['CARDINAL']},
#  'next year': {'count': 24, 'types': ['DATE']},
#  '30': {'count': 91, 'types': ['CARDINAL', 'DATE']},
#  'a day': {'count': 22, 'types': ['DATE']},
#  '1 o’clock': {'count': 6, 'types': ['TIME']},
#  '24': {'count': 7, 'types': ['CARDINAL']},
#  'a couple of days': {'count': 12, 'types': ['DATE']},
#  'this evening': {'count': 33, 'types': ['TIME']},
#  'three': {'count': 101, 'types': ['CARDINAL']},
#  'a month': {'count': 18, 'types': ['DATE']},
#  'Saturday': {'count': 41, 'types': ['DATE']},
#  'Helvoirt': {'count': 24, 'types': ['GPE', 'PERSON', 'WORK_OF_ART', 'ORG']},
#  'Brussels': {'count': 79, 'types': ['GPE']},
#  '3 days': {'count': 8, 'types': ['DATE']},
#  'hours': {'count': 5, 'types': ['TIME']},
#  'Katwijk': {'count': 10, 'types': ['GPE', 'PERSON']},
#  'the year': {'count': 17, 'types': ['DATE']},
#  'Parisian': {'count': 26, 'types': ['NORP']},
#  'Belgians': {'count': 8, 'types': ['NORP']},
#  'Le Chat Noir': {'count': 6, 'types': ['FAC']},
#  'late in the evening': {'count': 5, 'types': ['TIME']},
#  'Dupré': {'count': 6, 'types': ['PERSON', 'ORG']},
#  'Balzac': {'count': 7, 'types': ['PERSON']},
#  '50-franc': {'count': 35, 'types': ['MONEY']},
#  'Japan': {'count': 14, 'types': ['GPE']},
#  'Two': {'count': 24, 'types': ['CARDINAL']},
#  'Pécuchet': {'count': 5, 'types': ['GPE', 'PERSON']},
#  'some day': {'count': 18, 'types': ['DATE']},
#  'February': {'count': 14, 'types': ['DATE']},
#  '4 francs': {'count': 9, 'types': ['MONEY']},
#  '200 francs': {'count': 9, 'types': ['MONEY']},
#  '5': {'count': 58, 'types': ['CARDINAL', 'DATE']},
#  '10 metres': {'count': 10, 'types': ['QUANTITY']},
#  '40 francs': {'count': 5, 'types': ['MONEY']},
#  'five': {'count': 7, 'types': ['CARDINAL']},
#  'more than one': {'count': 26, 'types': ['CARDINAL']},
#  'the night': {'count': 13, 'types': ['TIME']},
#  'thirty years': {'count': 5, 'types': ['DATE']},
#  'Jewish': {'count': 19, 'types': ['NORP']},
#  'that day': {'count': 18, 'types': ['DATE']},
#  'France': {'count': 24, 'types': ['GPE']},
#  'autumn': {'count': 22, 'types': ['DATE']},
#  'these last few days': {'count': 13, 'types': ['DATE']},
#  'Christmas': {'count': 73, 'types': ['DATE']},
#  'These last few days': {'count': 10, 'types': ['DATE']},
#  'the evening': {'count': 26, 'types': ['TIME']},
#  'Paul': {'count': 22, 'types': ['PERSON']},
#  'Jesus Christ': {'count': 16, 'types': ['PERSON']},
#  'last night': {'count': 17, 'types': ['TIME']},
#  'Hoeven': {'count': 7, 'types': ['PERSON']},
#  'a hundred': {'count': 7, 'types': ['CARDINAL']},
#  'New Year': {'count': 20, 'types': ['EVENT']},
#  'Sower': {'count': 12, 'types': ['GPE', 'FAC']},
#  'Winter': {'count': 5, 'types': ['DATE']},
#  'the afternoon': {'count': 7, 'types': ['TIME']},
#  'daily': {'count': 34, 'types': ['DATE']},
#  'this summer': {'count': 76, 'types': ['DATE']},
#  'the days': {'count': 52, 'types': ['DATE']},
#  'Laan van Meerdervoort': {'count': 5, 'types': ['PERSON']},
#  'this month': {'count': 41, 'types': ['DATE']},
#  'every month': {'count': 7, 'types': ['DATE']},
#  '20 francs': {'count': 13, 'types': ['MONEY']},
#  'this very day': {'count': 5, 'types': ['DATE']},
#  'the present day': {'count': 11, 'types': ['DATE']},
#  'Frenchman': {'count': 6, 'types': ['NORP']},
#  'the last few years': {'count': 7, 'types': ['DATE']},
#  'Pont-Aven': {'count': 26, 'types': ['ORG']},
#  'a week': {'count': 25, 'types': ['DATE']},
#  '25': {'count': 12, 'types': ['CARDINAL', 'DATE']},
#  'Le Figaro': {'count': 7, 'types': ['FAC']},
#  'all day': {'count': 14, 'types': ['DATE']},
#  'Camargue': {'count': 9, 'types': ['PERSON', 'ORG']},
#  'the end of the week': {'count': 6, 'types': ['DATE']},
#  'the end of the month': {'count': 26, 'types': ['DATE']},
#  'grey': {'count': 9, 'types': ['PERSON', 'ORG']},
#  'Rijnspoor': {'count': 6, 'types': ['PERSON', 'ORG']},
#  'H.G.T.': {'count': 9, 'types': ['ORG']},
#  'ten': {'count': 13, 'types': ['CARDINAL']},
#  'Vie Moderne': {'count': 9, 'types': ['PERSON']},
#  '100': {'count': 13, 'types': ['CARDINAL']},
#  'a few hours': {'count': 10, 'types': ['TIME']},
#  'the end of March': {'count': 6, 'types': ['DATE']},
#  'Arles': {'count': 94, 'types': ['GPE', 'PERSON']},
#  'Belgian': {'count': 12, 'types': ['NORP']},
#  'Montmartre': {'count': 18, 'types': ['GPE', 'PERSON', 'LOC', 'ORG']},
#  'Virginia': {'count': 6, 'types': ['GPE']},
#  'four': {'count': 33, 'types': ['CARDINAL']},
#  'Adieu Vincent': {'count': 5, 'types': ['PERSON']},
#  'those days': {'count': 28, 'types': ['DATE']},
#  'England': {'count': 66, 'types': ['GPE']},
#  'America': {'count': 19, 'types': ['GPE']},
#  'Last Sunday': {'count': 16, 'types': ['DATE']},
#  'Trippenhuis': {'count': 7, 'types': ['PERSON']},
#  'Christian': {'count': 38, 'types': ['NORP']},
#  'Corot': {'count': 14, 'types': ['PERSON']},
#  'last month': {'count': 7, 'types': ['DATE']},
#  'Vincent van Gogh': {'count': 12, 'types': ['PERSON']},
#  'Utrecht': {'count': 25, 'types': ['GPE']},
#  'year': {'count': 21, 'types': ['DATE']},
#  'next month': {'count': 8, 'types': ['DATE']},
#  'Provence': {'count': 19, 'types': ['GPE', 'PRODUCT', 'ORG']},
#  'the 150 francs': {'count': 10, 'types': ['MONEY']},
#  'the coming days': {'count': 8, 'types': ['DATE']},
#  'This morning': {'count': 43, 'types': ['TIME']},
#  'Provençal': {'count': 11, 'types': ['GPE', 'PERSON', 'ORG']},
#  'Rijswijk': {'count': 9, 'types': ['GPE', 'PERSON', 'ORG']},
#  'Swiss': {'count': 5, 'types': ['NORP']},
#  'Friday': {'count': 27, 'types': ['DATE']},
#  'Schenkweg': {'count': 11, 'types': ['GPE', 'ORG']},
#  'this winter': {'count': 55, 'types': ['DATE']},
#  'last winter': {'count': 29, 'types': ['DATE']},
#  'Sien': {'count': 20, 'types': ['PERSON', 'ORG']},
#  'May': {'count': 20, 'types': ['DATE']},
#  '2 years': {'count': 8, 'types': ['DATE']},
#  'several days': {'count': 10, 'types': ['DATE']},
#  'Whatman': {'count': 10, 'types': ['PERSON']},
#  'a thousand': {'count': 10, 'types': ['CARDINAL']},
#  'a year ago': {'count': 5, 'types': ['DATE']},
#  'only one': {'count': 18, 'types': ['CARDINAL']},
#  'Love': {'count': 48, 'types': ['WORK_OF_ART']},
#  'Cuesmes': {'count': 6, 'types': ['GPE', 'ORG']},
#  'ten thousand': {'count': 5, 'types': ['CARDINAL']},
#  'Rappard': {'count': 8, 'types': ['GPE', 'PERSON']},
#  'last summer': {'count': 29, 'types': ['DATE']},
#  'recent days': {'count': 5, 'types': ['DATE']},
#  'March': {'count': 32, 'types': ['DATE']},
#  'the month': {'count': 18, 'types': ['DATE']},
#  'weeks': {'count': 7, 'types': ['DATE']},
#  '10 francs': {'count': 7, 'types': ['MONEY']},
#  '3 months': {'count': 8, 'types': ['DATE']},
#  'Ingres': {'count': 19, 'types': ['PERSON']},
#  '10': {'count': 62, 'types': ['CARDINAL', 'DATE']},
#  'next week': {'count': 14, 'types': ['DATE']},
#  'Vincent I': {'count': 18, 'types': ['PERSON']},
#  'midday': {'count': 13, 'types': ['TIME']},
#  'greenery': {'count': 19, 'types': ['ORG']},
#  'twentieth': {'count': 7, 'types': ['DATE']},
#  'Germans': {'count': 10, 'types': ['NORP']},
#  'June': {'count': 7, 'types': ['DATE']},
#  'New Year’s Eve': {'count': 9, 'types': ['EVENT']},
#  'a couple of days ago': {'count': 7, 'types': ['DATE']},
#  'the New Year': {'count': 10, 'types': ['DATE', 'EVENT']},
#  'Hon': {'count': 11, 'types': ['PERSON']},
#  'Greek': {'count': 22, 'types': ['NORP']},
#  'fifth': {'count': 5, 'types': ['ORDINAL']},
#  'Irish': {'count': 8, 'types': ['NORP']},
#  'Xmas': {'count': 14, 'types': ['PERSON', 'ORG']},
#  'The Graphic': {'count': 13, 'types': ['PERSON', 'WORK_OF_ART', 'ORG']},
#  'Richmond': {'count': 10, 'types': ['GPE']},
#  'Lewisham': {'count': 9, 'types': ['GPE']},
#  'Turnham Green': {'count': 9, 'types': ['PERSON', 'FAC', 'ORG']},
#  'Thou': {'count': 99, 'types': ['GPE', 'PERSON', 'ORG']},
#  'Thine': {'count': 8, 'types': ['ORG', 'GPE', 'NORP']},
#  'Thou hast': {'count': 5, 'types': ['PERSON']},
#  'the hour': {'count': 12, 'types': ['TIME']},
#  'the last few days': {'count': 17, 'types': ['DATE']},
#  'noon': {'count': 5, 'types': ['TIME']},
#  'Italy': {'count': 6, 'types': ['GPE']},
#  'Haarlem': {'count': 12, 'types': ['GPE', 'PERSON', 'LOC', 'ORG']},
#  'Tuesday': {'count': 12, 'types': ['DATE']},
#  'Jesus': {'count': 36, 'types': ['PERSON']},
#  'Bernard': {'count': 22, 'types': ['PERSON', 'ORG']},
#  'vineyards': {'count': 8, 'types': ['LOC']},
#  'Goupils': {'count': 16, 'types': ['WORK_OF_ART', 'ORG']},
#  '60': {'count': 9, 'types': ['CARDINAL']},
#  'another year': {'count': 8, 'types': ['DATE']},
#  'that year': {'count': 9, 'types': ['DATE']},
#  '20': {'count': 26, 'types': ['CARDINAL', 'DATE']},
#  'Geest': {'count': 12, 'types': ['PERSON', 'LOC']},
#  'Pangloss': {'count': 11, 'types': ['PERSON']},
#  'P.S.': {'count': 5, 'types': ['GPE']},
#  'Impressionism': {'count': 28, 'types': ['ORG', 'NORP']},
#  'Marseille': {'count': 54, 'types': ['GPE', 'PERSON', 'ORG']},
#  'Yours': {'count': 6, 'types': ['ORG']},
#  'the other day': {'count': 17, 'types': ['DATE']},
#  'Israëls': {'count': 23, 'types': ['GPE', 'PERSON', 'ORG']},
#  'Rhône': {'count': 6, 'types': ['NORP']},
#  'Veronese': {'count': 25, 'types': ['PERSON', 'NORP']},
#  'Aix': {'count': 6, 'types': ['GPE', 'NORP']},
#  'Tambourin': {'count': 5, 'types': ['GPE', 'FAC']},
#  'two months': {'count': 7, 'types': ['DATE']},
#  'Zouaves': {'count': 7, 'types': ['PERSON']},
#  'two years': {'count': 10, 'types': ['DATE']},
#  'Vincent As': {'count': 7, 'types': ['PERSON']},
#  '100-franc': {'count': 16, 'types': ['MONEY']},
#  'Daumier': {'count': 11, 'types': ['GPE', 'PERSON', 'ORG']},
#  'Herewith': {'count': 11, 'types': ['PERSON', 'WORK_OF_ART', 'ORG']},
#  'six': {'count': 6, 'types': ['CARDINAL']},
#  'thousand': {'count': 20, 'types': ['CARDINAL']},
#  'Delacroix': {'count': 19, 'types': ['PERSON']},
#  'Zandvoort': {'count': 7, 'types': ['GPE', 'PERSON']},
#  'early this morning': {'count': 8, 'types': ['TIME']},
#  'Tartarin': {'count': 18, 'types': ['GPE', 'LANGUAGE', 'PERSON', 'NORP']},
#  'This afternoon': {'count': 8, 'types': ['TIME']},
#  'dozen': {'count': 5, 'types': ['CARDINAL']},
#  '4 days': {'count': 5, 'types': ['DATE']},
#  '1 franc': {'count': 10, 'types': ['MONEY']},
#  '15': {'count': 9, 'types': ['CARDINAL', 'DATE']},
#  'Vincent Please': {'count': 5, 'types': ['PERSON']},
#  '3 francs': {'count': 5, 'types': ['MONEY']},
#  'Mediterranean': {'count': 9, 'types': ['LOC']},
#  '300': {'count': 6, 'types': ['CARDINAL']},
#  'Thomas': {'count': 5, 'types': ['PERSON']},
#  'Englishman': {'count': 5, 'types': ['PERSON']},
#  'Gréville': {'count': 6, 'types': ['GPE', 'PERSON', 'ORG']},
#  'Spring': {'count': 5, 'types': ['DATE']},
#  'the Garden of Olives': {'count': 6, 'types': ['FAC']},
#  'Barbizon': {'count': 8, 'types': ['LOC', 'FAC']},
#  'half a year': {'count': 7, 'types': ['DATE']},
#  'New York': {'count': 6, 'types': ['GPE']},
#  'one night': {'count': 5, 'types': ['TIME']},
#  'Sundays': {'count': 6, 'types': ['DATE']},
#  'at least one': {'count': 8, 'types': ['CARDINAL']},
#  'Time': {'count': 5, 'types': ['ORG']},
#  'Hoogeveen': {'count': 18, 'types': ['DATE']},
#  'Goupil': {'count': 25, 'types': ['GPE', 'PERSON']},
#  'Ireland': {'count': 9, 'types': ['GPE']},
#  '17': {'count': 6, 'types': ['CARDINAL', 'DATE']},
#  'Renaissance': {'count': 7, 'types': ['ORG']},
#  'Terschelling': {'count': 13, 'types': ['GPE', 'LANGUAGE', 'LOC', 'NORP']},
#  'the 100 francs': {'count': 5, 'types': ['MONEY']},
#  'Isleworth': {'count': 5, 'types': ['PERSON']},
#  'Tarascon': {'count': 16, 'types': ['GPE', 'PERSON', 'ORG']},
#  'the next day': {'count': 11, 'types': ['DATE']},
#  'Flemish': {'count': 10, 'types': ['LANGUAGE', 'NORP']},
#  'the beginning of the year': {'count': 5, 'types': ['DATE']},
#  'so many years': {'count': 5, 'types': ['DATE']},
#  'a morning': {'count': 5, 'types': ['TIME']},
#  'many years': {'count': 7, 'types': ['DATE']},
#  'This winter': {'count': 5, 'types': ['DATE']},
#  'Arab': {'count': 5, 'types': ['NORP']},
#  'This evening': {'count': 6, 'types': ['TIME']},
#  'Adam Bede': {'count': 6, 'types': ['GPE', 'PERSON']},
#  'a penny': {'count': 8, 'types': ['MONEY']},
#  'Peter': {'count': 6, 'types': ['PERSON']},
#  '40': {'count': 5, 'types': ['CARDINAL', 'DATE']},
#  'the end of a year': {'count': 8, 'types': ['DATE']},
#  'the past year': {'count': 5, 'types': ['DATE']},
#  'Welwyn': {'count': 8, 'types': ['GPE']},
#  '250 francs': {'count': 6, 'types': ['MONEY']},
#  'Second': {'count': 6, 'types': ['ORDINAL']},
#  'Lhermitte': {'count': 6, 'types': ['ORG']},
#  '1 year': {'count': 5, 'types': ['DATE']},
#  '2 years ago': {'count': 6, 'types': ['DATE']},
#  'C.M.': {'count': 24, 'types': ['NORP', 'ORG']},
#  'Baarn': {'count': 5, 'types': ['PERSON']},
#  '21 May': {'count': 5, 'types': ['DATE']},
#  'St-Rémy': {'count': 18, 'types': ['FAC', 'ORG']},
#  'Pietà': {'count': 6, 'types': ['PERSON']},
#  'Black and White': {'count': 7, 'types': ['LOC']},
#  'Egyptian': {'count': 7, 'types': ['NORP']},
#  'Mouret': {'count': 15, 'types': ['PERSON', 'ORG']},
#  'Mme François': {'count': 7, 'types': ['GPE', 'PERSON']},
#  'Berceuse': {'count': 11, 'types': ['ORG']},
#  'Roulin': {'count': 6, 'types': ['GPE']},
#  'Sensier': {'count': 5, 'types': ['PERSON', 'ORG']},
#  'Greeks': {'count': 12, 'types': ['PERSON']},
#  'Danish': {'count': 5, 'types': ['NORP']},
#  'Moniteur Universel': {'count': 5, 'types': ['ORG']},
#  'Dick': {'count': 6, 'types': ['PERSON']},
#  'Harry': {'count': 6, 'types': ['PERSON']},
#  'Le': {'count': 6, 'types': ['GPE', 'ORG', 'FAC']},
#  '2.50 guilders': {'count': 5, 'types': ['MONEY']},
#  '20 guilders': {'count': 6, 'types': ['MONEY']},
#  'three days': {'count': 7, 'types': ['DATE']},
#  'the end of this month': {'count': 6, 'types': ['DATE']},
#  'tonight': {'count': 5, 'types': ['TIME']},
#  'Gethsemane': {'count': 6, 'types': ['GPE', 'PERSON', 'ORG']},
#  'Vincent Regards': {'count': 5, 'types': ['PERSON']},
#  'next Sunday': {'count': 5, 'types': ['DATE']},
#  'only yesterday': {'count': 5, 'types': ['DATE']},
#  'December': {'count': 5, 'types': ['DATE']},
#  'Germinal': {'count': 6, 'types': ['GPE']},
#  '4 o’clock': {'count': 7, 'types': ['TIME']},
#  'only half': {'count': 17, 'types': ['CARDINAL']},
#  'Bid': {'count': 7, 'types': ['PERSON']},
#  'Kee': {'count': 6, 'types': ['PERSON', 'LOC']},
#  'Scotland': {'count': 13, 'types': ['GPE']},
#  'Rey': {'count': 5, 'types': ['PERSON']},
#  'Rembrandt': {'count': 22, 'types': ['GPE', 'PERSON', 'NORP', 'ORG']},
#  'Israel': {'count': 16, 'types': ['GPE']},
#  'the end of January': {'count': 5, 'types': ['DATE']},
#  'Geel': {'count': 9, 'types': ['GPE', 'PRODUCT', 'PERSON']},
#  'Adieu Theo': {'count': 5, 'types': ['PERSON']},
#  '300 francs': {'count': 5, 'types': ['MONEY']},
#  'Emmaus': {'count': 8, 'types': ['GPE']},
#  'half a dozen': {'count': 6, 'types': ['CARDINAL']},
#  'Nice': {'count': 6, 'types': ['GPE']},
#  'half an hour': {'count': 6, 'types': ['TIME']},
#  'Scottish': {'count': 7, 'types': ['NORP']},
#  'the last days': {'count': 5, 'types': ['DATE']},
#  '14': {'count': 5, 'types': ['CARDINAL']},
#  'Jew': {'count': 5, 'types': ['NORP']},
#  'Notre-Dame': {'count': 7, 'types': ['FAC']},
#  'the Grote Kerk': {'count': 5, 'types': ['ORG', 'FAC']},
#  'Jerusalem': {'count': 5, 'types': ['GPE']},
#  'Buitenkant': {'count': 9, 'types': ['PERSON']},
#  'J.P.S.': {'count': 25, 'types': ['GPE', 'ORG']},
#  'a couple of years': {'count': 5, 'types': ['DATE']},
#  'Italians': {'count': 15, 'types': ['NORP']},
#  'Spaniards': {'count': 9, 'types': ['NORP']},
#  'Assen': {'count': 7, 'types': ['GPE', 'PERSON']},
#  'just one': {'count': 6, 'types': ['CARDINAL']},
#  'Vincent It': {'count': 6, 'types': ['PERSON']},
#  'some days': {'count': 5, 'types': ['DATE']},
#  'spring': {'count': 5, 'types': ['DATE']},
#  'one evening': {'count': 7, 'types': ['TIME']},
#  'a dozen': {'count': 5, 'types': ['CARDINAL']},
#  'Courrières': {'count': 9, 'types': ['PERSON', 'ORG']},
#  'Arabia': {'count': 5, 'types': ['GPE', 'PERSON']},
#  'Meryon': {'count': 6, 'types': ['PERSON']},
#  'Messrs': {'count': 11, 'types': ['GPE', 'PERSON']},
#  'Christs': {'count': 5, 'types': ['NORP']},
#  'Denmark': {'count': 5, 'types': ['GPE']},
#  'Morgana': {'count': 7, 'types': ['PERSON']},
#  'Chinese': {'count': 5, 'types': ['NORP']},
#  'Loosduinen': {'count': 8, 'types': ['GPE', 'PERSON']},
#  'Elisha': {'count': 11, 'types': ['PERSON']},
#  'Arise': {'count': 7, 'types': ['PERSON']},
#  'Ahab': {'count': 6, 'types': ['PERSON']},
#  'Baal': {'count': 6, 'types': ['GPE', 'PERSON', 'LOC']},
#  'Diggers': {'count': 5, 'types': ['ORG']},
#  '10 days': {'count': 7, 'types': ['DATE']},
#  'the Jewish quarter': {'count': 5, 'types': ['DATE']},
#  'Thijs Maris': {'count': 5, 'types': ['PERSON']},
#  'Adieu': {'count': 7, 'types': ['PRODUCT', 'PERSON']},
#  'Latin': {'count': 13, 'types': ['LANGUAGE', 'NORP']},
#  'Bickerseiland': {'count': 5, 'types': ['GPE']},
#  'Mary': {'count': 7, 'types': ['PERSON']},
#  'John Halifax': {'count': 5, 'types': ['PERSON']},
#  'Fodor': {'count': 5, 'types': ['GPE']},
#  'the same day': {'count': 7, 'types': ['DATE']},
#  'Punch': {'count': 5, 'types': ['PRODUCT', 'LOC']},
#  'thirty': {'count': 7, 'types': ['CARDINAL']},
#  'Jan': {'count': 6, 'types': ['PERSON']},
#  'Rochussen': {'count': 5, 'types': ['GPE', 'PERSON']},
#  'Carlyle': {'count': 5, 'types': ['PERSON']},
#  'Uncle Cor': {'count': 6, 'types': ['PERSON', 'FAC']},
#  'Crau': {'count': 5, 'types': ['ORG']},
#  'Vincent Do': {'count': 6, 'types': ['PERSON']},
#  'Cromwell': {'count': 11, 'types': ['PERSON', 'ORG']},
#  'Richard': {'count': 6, 'types': ['PERSON']},
#  'Ludlow': {'count': 5, 'types': ['PERSON']},
#  'Angel': {'count': 7, 'types': ['PERSON']},
#  'Harlem': {'count': 10, 'types': ['LOC']},
#  'Voorburg': {'count': 6, 'types': ['GPE']},
#  'Petersham': {'count': 5, 'types': ['ORG']},
#  'Theagenes': {'count': 5, 'types': ['PERSON']},
#  'Van de Loo': {'count': 5, 'types': ['PERSON']}}

# %% [markdown]
# As we can see a lot of the entities found are not that interesting, especially does from the CARDINAL and ORDINAL type since they are just numbers that are either ordinal or do not fall on any other category, so they will be filtered out.

# %% [markdown]
# # Sentiment Analysis Individual Entities and Nouns
# ## Looking at sentiments of main entities

# %%
# Setting up necessary analyzers
nlp = spacy.load('en_core_web_sm')
analyzer = SentimentIntensityAnalyzer()

# Setting up default dictionaries to keep track of each entity's sentiment scores and frequencies
entity_sentiments = defaultdict(list)  # Missing values default to []
entity_frequencies = defaultdict(int)  # Missing values default to 0

# Going through all letters
for letter in sentiment_letters['Translation']:
    doc = nlp(letter)  # Tokenize the text into a SpaCy Doc object

    # Going through all sentences in each letter
    for sent in doc.sents:  # Iterating over each sentence
        sentiment = analyzer.polarity_scores(sent.text)['compound']  # Get compound sentiment score for the sentence

        # Iterating over each entity in the sentence
        for ent in sent.ents:  # Extracting named entities
            if ent.label_ not in ['CARDINAL', 'ORDINAL']:  # Exclude CARDINAL and ORDINAL entities
                entity_text = ent.text  
                entity_frequencies[entity_text] += 1  # Increment frequency count
                entity_sentiments[entity_text].append(sentiment)  # Append sentiment score for this entity

# Creating a dictionary that combines entity_sentiments and entity_frequencies
entity_analysis = {
    entity: {
        'frequency': freq,
        'all_sentiments': entity_sentiments[entity],
        'avg_sentiment': sum(entity_sentiments[entity]) / len(entity_sentiments[entity]),
        'min_sentiment': min(entity_sentiments[entity]),
        'max_sentiment': max(entity_sentiments[entity]),
        'sentiment_variance': sum((x - sum(entity_sentiments[entity]) / len(entity_sentiments[entity]))**2
                                  for x in entity_sentiments[entity]) / len(entity_sentiments[entity])
    }
    for entity, freq in entity_frequencies.items()
}

# %%
# only selecting words that were mentioned at least 5 times
filtered_entities = {noun: data for noun, data in entity_analysis.items() if data['frequency'] >= 5}

# sorting the filtered entities by frequency in descending order
sorted_entities = sorted(filtered_entities.items(), key=lambda x: x[1]['frequency'], reverse=True)

# building the final summary dictionary
summary_entities = {}
for entity, data in sorted_entities:
    sentiment = data['avg_sentiment']
    variance = data['sentiment_variance']
    sentiment_label = 'positive' if sentiment > 0.05 else 'negative' if sentiment < -0.05 else 'neutral'

    summary_entities[entity] = {
        'frequency': data['frequency'],
        'sentiment': sentiment_label,
        'average_sentiment': round(data['avg_sentiment'], 2),
        'tone_variance': round(variance, 2),
        'all_sentiments': data['all_sentiments'],
        'min_sentiment':round(data['min_sentiment'], 2),
        'max_sentiment':round(data['max_sentiment'], 2)
    }

entity_sentiment_df = pd.DataFrame.from_dict(summary_entities, orient='index')
entity_sentiment_df.head()
# Out:
#          frequency sentiment  average_sentiment  tone_variance  \
# Theo           951  positive               0.44           0.14
# Vincent        604  positive               0.25           0.10
# Paris          555  positive               0.23           0.17
# today          337  positive               0.22           0.17
# London         187  positive               0.26           0.17
#
#                                             all_sentiments  min_sentiment  \
# Theo     [0.3818, 0.0, 0.3818, 0.8508, 0.8109, 0.6808, ...          -0.92
# Vincent  [0.2732, 0.4404, 0.5598, 0.4404, 0.4404, 0.0, ...          -0.95
# Paris    [0.6908, 0.0, 0.3182, -0.1027, 0.2732, -0.7003...          -0.93
# today    [0.235, 0.235, 0.7003, 0.6115, 0.4404, 0.5346,...          -0.85
# London   [0.7501, -0.3804, -0.3804, 0.0, -0.1027, 0.0, ...          -0.90
#
#          max_sentiment
# Theo              0.98
# Vincent           0.99
# Paris             0.94
# today             0.95
# London            0.93

# %%
entity_sentiment_df[entity_sentiment_df["average_sentiment"] > 0.7]
# Out:
#            frequency sentiment  average_sentiment  tone_variance  \
# Love              48  positive               0.74           0.08
# Comforter          5  positive               0.77           0.01
#
#                                               all_sentiments  min_sentiment  \
# Love       [0.765, 0.8979, 0.6697, 0.9508, 0.9265, 0.9631...          -0.15
# Comforter           [0.8658, 0.9001, 0.8158, 0.6517, 0.6124]           0.61
#
#            max_sentiment
# Love                0.99
# Comforter           0.90

# %%
# resetting the index 
entity_sentiment_df = entity_sentiment_df.reset_index()

# making a new column called Entity for each entity 
entity_sentiment_df = entity_sentiment_df.rename(columns={'index': 'Entity'})  # If 'index' was the name of your entity column

# plotting top 10 Entities by Frequency
plt.figure(figsize=(12, 8))

# selecting top 10 columns based on frequency
top_entities = entity_sentiment_df.nlargest(10, 'frequency')

# Use barplot to display the top entities by frequency
sns.barplot(data=top_entities, x='frequency', y='Entity', color = 'red')

plt.title('Top 10 Entities by Frequency', fontsize=16)
plt.xlabel('Frequency', fontsize=12)
plt.ylabel('Entity', fontsize=12)
plt.tight_layout()
plt.show()

# %%
# Out:
#        Noun  frequency sentiment  average_sentiment  tone_variance  \
# 0     thing       3329  positive               0.23           0.22
# 1      time       2470  positive               0.18           0.20
# 2       day       1856  positive               0.20           0.21
# 3      work       1602  positive               0.26           0.21
# 4  painting       1582  positive               0.22           0.19
# 5       way       1436  positive               0.19           0.21
# 6    letter       1405  positive               0.31           0.16
# 7    people       1307  positive               0.20           0.23
# 8      life       1206  positive               0.21           0.27
# 9   drawing       1156  positive               0.21           0.15
#
#                                       all_sentiments  min_sentiment  \
# 0  [0.3919, 0.6444, 0.0, 0.1027, 0.0, 0.8508, 0.1...          -0.96
# 1  [-0.1531, 0.8957, 0.0, 0.875, 0.2732, -0.4767,...          -0.96
# 2  [0.0, 0.0, 0.3818, 0.3321, 0.743, 0.0, 0.3818,...          -0.98
# 3  [0.0, -0.8663, 0.8519, 0.7501, 0.7876, 0.3612,...          -0.95
# 4  [-0.1531, -0.0258, 0.4404, 0.6908, 0.6361, 0.2...          -0.94
# 5  [0.0, 0.0, 0.875, 0.8338, -0.8663, 0.6908, -0....          -0.93
# 6  [0.7783, 0.0, 0.0, 0.6808, 0.6124, 0.101, 0.62...          -0.93
# 7  [0.0, 0.4404, 0.7501, 0.2732, 0.8639, 0.7939, ...          -0.98
# 8  [0.2732, 0.235, 0.4404, 0.8221, 0.9017, 0.3612...          -0.98
# 9  [0.6486, -0.8663, 0.7458, 0.0, 0.0, -0.1027, 0...          -0.93
#
#    max_sentiment
# 0           0.99
# 1           0.98
# 2           0.99
# 3           0.99
# 4           0.96
# 5           0.99
# 6           0.98
# 7           0.99
# 8           0.99
# 9           0.96

# %%
# Create a new DataFrame that will have 'Entity' and a single row per sentiment score
expanded_df = top_entities.explode('all_sentiments')

# Plot the violin plot
plt.figure(figsize=(14, 8))
sns.boxplot(data=expanded_df, x='Entity', y='all_sentiments', color='pink')
plt.title('Sentiment Distribution for Top 10 Entities', fontsize=16)
plt.xlabel('Entity', fontsize=12)
plt.ylabel('Sentiment Score', fontsize=12)
plt.xticks(rotation=45, fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## looking at most common nouns and sentiment towards them

# %%
# setting up necessary analyzers
nlp = spacy.load('en_core_web_sm')
analyzer = SentimentIntensityAnalyzer()

# setting up default dictionaries to keep track of each nouns sentiment scores and frequencies 
# default dictionaries are used to avoid handling cases where a key does not already exist in the dictionary
noun_sentiments = defaultdict(list) # missing values as [] 
noun_frequencies = defaultdict(int) # 

# going through all letters 
for letter in sentiment_letters['Translation']:
    doc = nlp(letter) # needed for spacy to tokenize the text in such a way it becomes a DOC object 

    # going through all sentences in each letter 
    for sent in doc.sents: # doc.sents in spacy is used to iterate over each sentence in each letter
        sentiment = analyzer.polarity_scores(sent.text)['compound'] #get compound sentiment scores for each sentence 

        # iterating over each word/token 
        # extracting nouns, lemmatizing (so words like paintings and painting) get grouped together, and finding frequency of each word  
        for token in sent:
            if token.pos_ in ['NOUN', 'PROPN']: # spacy uses part-of-speech tagging to classify words
                lemma = token.lemma_.lower() # changing all words to lowercase 
                noun_frequencies[lemma] += 1 # adding each noun as a 
                noun_sentiments[lemma].append(sentiment) 

# creating a dictionary that combines noun_sentiments and noun_frequencies   
noun_analysis = {
    noun: {
        'frequency': freq,
        'avg_sentiment': sum(noun_sentiments[noun]) / len(noun_sentiments[noun]),
        'all_sentiments': noun_sentiments[noun],
        'min_sentiment': min(noun_sentiments[noun]),
        'max_sentiment': max(noun_sentiments[noun]),
        'sentiment_variance': sum((x - sum(noun_sentiments[noun])/len(noun_sentiments[noun]))**2 
                               for x in noun_sentiments[noun]) / len(noun_sentiments[noun])
    }
    for noun, freq in noun_frequencies.items()
}

# %%
# only selecting words that were mentioned at least 5 times
#filtered_nouns = {noun: data for noun, data in noun_analysis.items() if data['frequency'] >= 5}

# sorting the filtered nouns by frequency in descending order
sorted_nouns = sorted(noun_analysis.items(), key=lambda x: x[1]['frequency'], reverse=True)

# building the final summary dictionary
summary_nouns = {}
for noun, data in sorted_nouns:
    sentiment = data['avg_sentiment']
    variance = data['sentiment_variance']
    sentiment_label = 'positive' if sentiment > 0.05 else 'negative' if sentiment < -0.05 else 'neutral'

    summary_nouns[noun] = {
        'frequency': data['frequency'],
        'sentiment': sentiment_label,
        'average_sentiment': round(data['avg_sentiment'], 2),
        'tone_variance': round(variance, 2),
        'all_sentiments': data['all_sentiments'],noun_sentiment_df[(noun_sentiment_df["average_sentiment"] > 0.9) & (noun_sentiment_df["frequency"] > 2)]

        'min_sentiment':round(data['min_sentiment'], 2),
        'max_sentiment':round(data['max_sentiment'], 2)
    }

noun_sentiment_df = pd.DataFrame.from_dict(summary_nouns, orient='index')
noun_sentiment_df.head()
# Out:
#           frequency sentiment  average_sentiment  tone_variance  \
# thing          3329  positive               0.23           0.22
# time           2470  positive               0.18           0.20
# day            1856  positive               0.20           0.21
# work           1602  positive               0.26           0.21
# painting       1582  positive               0.22           0.19
#
#                                              all_sentiments  min_sentiment  \
# thing     [0.3919, 0.6444, 0.0, 0.1027, 0.0, 0.8508, 0.1...          -0.96
# time      [-0.1531, 0.8957, 0.0, 0.875, 0.2732, -0.4767,...          -0.96
# day       [0.0, 0.0, 0.3818, 0.3321, 0.743, 0.0, 0.3818,...          -0.98
# work      [0.0, -0.8663, 0.8519, 0.7501, 0.7876, 0.3612,...          -0.95
# painting  [-0.1531, -0.0258, 0.4404, 0.6908, 0.6361, 0.2...          -0.94
#
#           max_sentiment
# thing              0.99
# time               0.98
# day                0.99
# work               0.99
# painting           0.96

# %%
noun_sentiment_df[(noun_sentiment_df["average_sentiment"] < -0.7) & (noun_sentiment_df["frequency"] > 2)]
# Out:
#            frequency sentiment  average_sentiment  tone_variance  \
# prussians          3  negative              -0.93           0.00
# stab               3  negative              -0.73           0.02
# distrust           3  negative              -0.72           0.01
# murder             3  negative              -0.84           0.01
# bastard            3  negative              -0.80           0.02
# broken             3  negative              -0.78           0.01
# assault            3  negative              -0.82           0.01
#
#                         all_sentiments  min_sentiment  max_sentiment
# prussians  [-0.8957, -0.9485, -0.9485]          -0.95          -0.90
# stab        [-0.5859, -0.7096, -0.886]          -0.89          -0.59
# distrust   [-0.8086, -0.7906, -0.5719]          -0.81          -0.57
# murder      [-0.9001, -0.6808, -0.926]          -0.93          -0.68
# bastard    [-0.8979, -0.8834, -0.6124]          -0.90          -0.61
# broken       [-0.6808, -0.7297, -0.93]          -0.93          -0.68
# assault    [-0.7351, -0.9531, -0.7783]          -0.95          -0.74

# %%
# resetting the index 
noun_sentiment_df = noun_sentiment_df.reset_index()

# making a new column called Entity for each entity 
noun_sentiment_df = noun_sentiment_df.rename(columns={'index': 'Noun'})  # If 'index' was the name of your entity column

# plotting top 10 Entities by Frequency
plt.figure(figsize=(12, 8))

# selecting top 10 columns based on frequency
top_nouns = noun_sentiment_df.nlargest(10, 'frequency')

# Use barplot to display the top entities by frequency
sns.barplot(data=top_nouns, x='frequency', y='Noun', color = 'purple')

plt.title('Top 10 Nouns by Frequency', fontsize=16)
plt.xlabel('Frequency', fontsize=12)
plt.ylabel('Nouns', fontsize=12)
plt.tight_layout()
plt.show()

# %%
# Create a new DataFrame that will have 'Entity' and a single row per sentiment score
expanded_noun_df = top_nouns.explode('all_sentiments')

# Plot the violin plot
plt.figure(figsize=(14, 8))
sns.boxplot(data=expanded_noun_df, x='Noun', y='all_sentiments', color='lightgreen')
plt.title('Sentiment Distribution for Top 10 Nouns', fontsize=16)
plt.xlabel('Noun', fontsize=12)
plt.ylabel('Sentiment Score', fontsize=12)
plt.xticks(rotation=45, fontsize=10)
plt.tight_layout()
plt.show()
